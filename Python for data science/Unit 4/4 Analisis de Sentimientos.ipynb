# %% [markdown]
# # ¿Cómo instalar la base de datos nltk?

# %% [markdown]
# Desde la consola: python -m nltk.downloader all

# %%
pip install nltk

# %% [markdown]
# # Obtención de los datos.

# %% [markdown]
# https://www.nltk.org/

# %%
import nltk
from nltk.corpus import movie_reviews

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %% [markdown]
# http://www.nltk.org/nltk_data/

# %%
# para asegurarnos de que se usen los datos correctos 
from nltk.corpus import movie_reviews

# %%
movie_reviews.categories()
# Out:
# ['neg', 'pos']

# %%
movie_reviews.fileids()
# Out:
# ['neg/cv000_29416.txt',
#  'neg/cv001_19502.txt',
#  'neg/cv002_17424.txt',
#  'neg/cv003_12683.txt',
#  'neg/cv004_12641.txt',
#  'neg/cv005_29357.txt',
#  'neg/cv006_17022.txt',
#  'neg/cv007_4992.txt',
#  'neg/cv008_29326.txt',
#  'neg/cv009_29417.txt',
#  'neg/cv010_29063.txt',
#  'neg/cv011_13044.txt',
#  'neg/cv012_29411.txt',
#  'neg/cv013_10494.txt',
#  'neg/cv014_15600.txt',
#  'neg/cv015_29356.txt',
#  'neg/cv016_4348.txt',
#  'neg/cv017_23487.txt',
#  'neg/cv018_21672.txt',
#  'neg/cv019_16117.txt',
#  'neg/cv020_9234.txt',
#  'neg/cv021_17313.txt',
#  'neg/cv022_14227.txt',
#  'neg/cv023_13847.txt',
#  'neg/cv024_7033.txt',
#  'neg/cv025_29825.txt',
#  'neg/cv026_29229.txt',
#  'neg/cv027_26270.txt',
#  'neg/cv028_26964.txt',
#  'neg/cv029_19943.txt',
#  'neg/cv030_22893.txt',
#  'neg/cv031_19540.txt',
#  'neg/cv032_23718.txt',
#  'neg/cv033_25680.txt',
#  'neg/cv034_29446.txt',
#  'neg/cv035_3343.txt',
#  'neg/cv036_18385.txt',
#  'neg/cv037_19798.txt',
# ...

# %%
movie_reviews.words('neg/cv000_29416.txt')
# Out:
# ['plot', ':', 'two', 'teen', 'couples', 'go', 'to', ...]

# %%
movie_reviews.words('neg/cv002_17424.txt')
# Out:
# ['it', 'is', 'movies', 'like', 'these', 'that', 'make', ...]

# %% [markdown]
# # Preparación de los datos.

# %% [markdown]
# https://www.nltk.org/book/ch06.html

# %%
documents = [(list(movie_reviews.words(fileid)), category)
              for category in movie_reviews.categories()
              for fileid in movie_reviews.fileids(category)]

# %% [markdown]
# ### Mezclado aleatorio de los documentos.
# https://docs.python.org/3/library/random.html

# %%
# la base de datos está ordenada, primero los negativos y luego los positivos, hay que ponerlos mezclados
import random
random.seed(100)
random.shuffle(documents)

# %%
len(documents)
# Out:
# 2000

# %%
len(documents[0])
# Out:
# 2

# %%
documents[0]
# Out:
# (['i',
#   'was',
#   'fortunate',
#   'enough',
#   'to',
#   'attend',
#   'an',
#   'advance',
#   'screening',
#   'for',
#   'the',
#   'upcoming',
#   'thriller',
#   'conspiracy',
#   'theory',
#   '.',
#   'this',
#   'was',
#   ',',
#   'of',
#   'course',
#   ',',
#   'a',
#   'big',
#   'deal',
#   'for',
#   'me',
#   'because',
#   'reviewing',
#   'movies',
#   'is',
#   'basically',
#   'just',
#   'a',
#   'hobby',
#   'for',
#   'me',
#   'and',
#   'i',
#   'never',
#   'get',
#   'a',
#   'chance',
#   'at',
#   'something',
#   'like',
#   'this',
#   '.',
#   'not',
#   'only',
#   'did',
#   'i',
#   'get',
#   'to',
#   'see',
#   'an',
#   'advance',
#   'screening',
#   ',',
#   'i',
#   'was',
#   'able',
#   'to',
#   'see',
#   'an',
#   'advance',
#   'screening',
#   'of',
#   'a',
#   '*',
#   'very',
#   'good',
#   '*',
#   'movie',
#   '.',
#   'the',
#   'very',
#   'fast',
#   '-',
#   'paced',
#   'film',
#   'stars',
#   'mel',
#   'gibson',
# ...

# %%
text, opinion = documents[0]
print(text)
print()
print(opinion)
# Out:
# ['i', 'was', 'fortunate', 'enough', 'to', 'attend', 'an', 'advance', 'screening', 'for', 'the', 'upcoming', 'thriller', 'conspiracy', 'theory', '.', 'this', 'was', ',', 'of', 'course', ',', 'a', 'big', 'deal', 'for', 'me', 'because', 'reviewing', 'movies', 'is', 'basically', 'just', 'a', 'hobby', 'for', 'me', 'and', 'i', 'never', 'get', 'a', 'chance', 'at', 'something', 'like', 'this', '.', 'not', 'only', 'did', 'i', 'get', 'to', 'see', 'an', 'advance', 'screening', ',', 'i', 'was', 'able', 'to', 'see', 'an', 'advance', 'screening', 'of', 'a', '*', 'very', 'good', '*', 'movie', '.', 'the', 'very', 'fast', '-', 'paced', 'film', 'stars', 'mel', 'gibson', 'as', 'jerry', 'fletcher', ',', 'a', 'fast', '-', 'talking', ',', 'witty', ',', 'comical', 'taxi', 'driver', 'in', 'new', 'york', 'city', '.', 'gibson', "'", 's', 'performance', 'is', 'terrific', ',', 'and', 'his', 'character', 'is', 'similar', 'to', 'that', 'of', 'martin', 'riggs', 'in', 'the', 'lethal', 'weapon', 'films', '.', 'gibso
# ...

# %% [markdown]
# # Identifiquemos las palabras más utilizadas.

# %%
all_words = nltk.FreqDist(w.lower() for w in movie_reviews.words())
all_words
# Out:
# FreqDist({',': 77717, 'the': 76529, '.': 65876, 'a': 38106, 'and': 35576, 'of': 34123, 'to': 31937, "'": 30585, 'is': 25195, 'in': 21822, ...})

# %%
len(all_words)
# Out:
# 39768

# %%
# para mostrar las 5000 que más se repiten
word_features = list(all_words)[:5000]
word_features
# Out:
# [',',
#  'the',
#  '.',
#  'a',
#  'and',
#  'of',
#  'to',
#  "'",
#  'is',
#  'in',
#  's',
#  '"',
#  'it',
#  'that',
#  '-',
#  ')',
#  '(',
#  'as',
#  'with',
#  'for',
#  'his',
#  'this',
#  'film',
#  'i',
#  'he',
#  'but',
#  'on',
#  'are',
#  't',
#  'by',
#  'be',
#  'one',
#  'movie',
#  'an',
#  'who',
#  'not',
#  'you',
#  'from',
#  'at',
#  'was',
#  'have',
#  'they',
#  'has',
#  'her',
#  'all',
#  '?',
#  'there',
#  'like',
#  'so',
#  'out',
#  'about',
#  'up',
#  'more',
#  'what',
#  'when',
#  'which',
#  'or',
#  'she',
#  'their',
#  ':',
#  'some',
#  'just',
#  'can',
#  'if',
#  'we',
#  'him',
#  'into',
#  'even',
#  'only',
#  'than',
#  'no',
#  'good',
#  'time',
#  'most',
#  'its',
#  'will',
#  'story',
#  'would',
#  'been',
#  'much',
#  'character',
#  'also',
#  'get',
#  'other',
#  'do',
#  'two',
#  'well',
#  'them',
#  'very',
#  'characters',
#  ';',
#  'first',
#  '--',
#  'after',
#  'see',
#  '!',
#  'way',
#  'because',
# ...

# %%
len(word_features)
# Out:
# 5000

# %% [markdown]
# # Función para extraer cuales de las 5000 palabras existen en una reseña.

# %%
# esta funcion va a revisar si cada una de las palabras se encuentra en el documento que le especifiques
def document_features(documents):
    document_words = set(documents)
    features = {}
    for word in word_features:
        features['contains({})'.format(word)] = (word in document_words)
    return features

# %%
# le indicas el documento y la columna que quieres revisar
document_features(documents[0][0])
# Out:
# {'contains(,)': True,
#  'contains(the)': True,
#  'contains(.)': True,
#  'contains(a)': True,
#  'contains(and)': True,
#  'contains(of)': True,
#  'contains(to)': True,
#  "contains(')": True,
#  'contains(is)': True,
#  'contains(in)': True,
#  'contains(s)': True,
#  'contains(")': True,
#  'contains(it)': True,
#  'contains(that)': True,
#  'contains(-)': True,
#  'contains())': True,
#  'contains(()': True,
#  'contains(as)': True,
#  'contains(with)': True,
#  'contains(for)': True,
#  'contains(his)': True,
#  'contains(this)': True,
#  'contains(film)': True,
#  'contains(i)': True,
#  'contains(he)': True,
#  'contains(but)': True,
#  'contains(on)': True,
#  'contains(are)': True,
#  'contains(t)': True,
#  'contains(by)': True,
#  'contains(be)': True,
#  'contains(one)': True,
#  'contains(movie)': True,
#  'contains(an)': True,
#  'contains(who)': True,
#  'contains(not)': True,
#  'contains(you)': True,
#  'contains(from)': True,
#  'contains(at)': True,
# ...

# %% [markdown]
# # Repitamos lo anterior para todas las reseñas.

# %%
featuresets = [(document_features(d), c) for (d,c) in documents]

# %%
featuresets[0]
# Out:
# ({'contains(,)': True,
#   'contains(the)': True,
#   'contains(.)': True,
#   'contains(a)': True,
#   'contains(and)': True,
#   'contains(of)': True,
#   'contains(to)': True,
#   "contains(')": True,
#   'contains(is)': True,
#   'contains(in)': True,
#   'contains(s)': True,
#   'contains(")': True,
#   'contains(it)': True,
#   'contains(that)': True,
#   'contains(-)': True,
#   'contains())': True,
#   'contains(()': True,
#   'contains(as)': True,
#   'contains(with)': True,
#   'contains(for)': True,
#   'contains(his)': True,
#   'contains(this)': True,
#   'contains(film)': True,
#   'contains(i)': True,
#   'contains(he)': True,
#   'contains(but)': True,
#   'contains(on)': True,
#   'contains(are)': True,
#   'contains(t)': True,
#   'contains(by)': True,
#   'contains(be)': True,
#   'contains(one)': True,
#   'contains(movie)': True,
#   'contains(an)': True,
#   'contains(who)': True,
#   'contains(not)': True,
#   'contains(you)': True,
#   'contains(from)': True,
# ...

# %%
featuresets[0][1]
# Out:
# 'pos'

# %%
len(featuresets)
# Out:
# 2000

# %%
type(featuresets[0])
# Out:
# tuple

# %% [markdown]
# # Separación en conjunto de Entrenamiento y Prueba.

# %%
from sklearn.model_selection import train_test_split

# %%
train_set, test_set = train_test_split(featuresets, 
                                       test_size = 0.10, random_state = 100)

# %%
print(len(train_set))
print()
print(len(test_set))
# Out:
# 1800
#
# 200

# %% [markdown]
# # Clasificador Naive-Bayes.

# %% [markdown]
# ### Entrenando el Clasificador.

# %% [markdown]
# https://www.nltk.org/_modules/nltk/classify/naivebayes.html

# %%
classifier = nltk.NaiveBayesClassifier.train(train_set)

# %%
classifier.most_informative_features(20)
# Out:
# [('contains(outstanding)', True),
#  ('contains(stupidity)', True),
#  ('contains(coen)', True),
#  ('contains(taxi)', True),
#  ('contains(insulting)', True),
#  ('contains(ludicrous)', True),
#  ('contains(marvelous)', True),
#  ('contains(sucks)', True),
#  ('contains(wonderfully)', True),
#  ('contains(vulnerable)', True),
#  ('contains(idiotic)', True),
#  ('contains(winslet)', True),
#  ('contains(breathtaking)', True),
#  ('contains(finest)', True),
#  ('contains(schumacher)', True),
#  ('contains(maintains)', True),
#  ('contains(mulan)', True),
#  ('contains(ivy)', True),
#  ('contains(seagal)', True),
#  ('contains(beautifully)', True)]

# %%
classifier.show_most_informative_features(20)
# Out:
# Most Informative Features
#    contains(outstanding) = True              pos : neg    =     13.2 : 1.0
#      contains(stupidity) = True              neg : pos    =     10.8 : 1.0
#           contains(coen) = True              pos : neg    =     10.5 : 1.0
#           contains(taxi) = True              pos : neg    =     10.5 : 1.0
#      contains(insulting) = True              neg : pos    =     10.4 : 1.0
#      contains(ludicrous) = True              neg : pos    =     10.3 : 1.0
#      contains(marvelous) = True              pos : neg    =     10.0 : 1.0
#          contains(sucks) = True              neg : pos    =      9.6 : 1.0
#    contains(wonderfully) = True              pos : neg    =      9.0 : 1.0
#     contains(vulnerable) = True              pos : neg    =      8.3 : 1.0
#        contains(idiotic) = True              neg : pos    =      8.3 : 1.0
#        contains(winslet) = True              pos : neg    =      7.8 : 1.0
# ...

# %% [markdown]
# ### Probemos el Funcionamiento del Clasificador.

# %%
test_set[0]
# Out:
# ({'contains(,)': True,
#   'contains(the)': True,
#   'contains(.)': True,
#   'contains(a)': True,
#   'contains(and)': True,
#   'contains(of)': True,
#   'contains(to)': True,
#   "contains(')": True,
#   'contains(is)': True,
#   'contains(in)': True,
#   'contains(s)': True,
#   'contains(")': True,
#   'contains(it)': True,
#   'contains(that)': True,
#   'contains(-)': True,
#   'contains())': True,
#   'contains(()': True,
#   'contains(as)': True,
#   'contains(with)': True,
#   'contains(for)': True,
#   'contains(his)': True,
#   'contains(this)': True,
#   'contains(film)': True,
#   'contains(i)': True,
#   'contains(he)': True,
#   'contains(but)': True,
#   'contains(on)': True,
#   'contains(are)': True,
#   'contains(t)': True,
#   'contains(by)': True,
#   'contains(be)': True,
#   'contains(one)': True,
#   'contains(movie)': True,
#   'contains(an)': True,
#   'contains(who)': True,
#   'contains(not)': True,
#   'contains(you)': True,
#   'contains(from)': True,
# ...

# %%
classifier.classify(test_set[0][0])
# Out:
# 'neg'

# %% [markdown]
# # Matriz de confusión y reporte de clasificación.

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ### Etiquetas de entrenamiento.

# %%
y_train = []

for element in train_set:
    y_train.append(element[1])
    
y_train
# Out:
# ['pos',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'pos',
#  'pos',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'pos',
#  'pos',
#  'pos',
#  'pos',
#  'pos',
#  'pos',
#  'pos',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'pos',
#  'pos',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'pos',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
# ...

# %%
y_train_predict = []

for element in train_set:
    review = classifier.classify(element[0])
    y_train_predict.append(review)
    
y_train_predict
# Out:
# ['neg',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'pos',
#  'pos',
#  'pos',
#  'neg',
#  'pos',
#  'pos',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'pos',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'pos',
#  'pos',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
# ...

# %% [markdown]
# ### Comparación entre las etiquetas reales de los datos de Entrenamiento y las etiquetas encontradas por el clasificador.

# %%
cm = confusion_matrix(y_train, y_train_predict, labels=["pos", "neg"])

# %%
labels=["pos", "neg"]

sns.heatmap(cm, linewidth = 0.5, annot = True, cmap = 'Reds', fmt = 'g', 
            xticklabels=labels, yticklabels=labels)

plt.ylabel('Valores predecidos')
plt.xlabel('Valores reales')
plt.title('Comparación con valores de entrenamiento')
plt.show()

# %%
print(classification_report(y_train, y_train_predict))
# Out:
#               precision    recall  f1-score   support
#
#          neg       0.86      0.94      0.90       907
#          pos       0.94      0.85      0.89       893
#
#     accuracy                           0.90      1800
#    macro avg       0.90      0.89      0.89      1800
# weighted avg       0.90      0.90      0.89      1800

# %% [markdown]
# ### Etiquetas de prueba.

# %%
y_test = []

for element in test_set:
    y_test.append(element[1])
    
y_test
# Out:
# ['neg',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'pos',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'pos',
#  'pos',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'pos',
# ...

# %%
y_test_predict = []

for element in test_set:
    review = classifier.classify(element[0])
    y_test_predict.append(review)
    
y_test_predict
# Out:
# ['neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'pos',
#  'pos',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'pos',
#  'pos',
#  'pos',
#  'pos',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'pos',
#  'pos',
#  'pos',
# ...

# %% [markdown]
# ### Comparación entre las etiquetas reales de los datos de Prueba y las etiquetas encontradas por el clasificador.

# %%
cm = confusion_matrix(y_test, y_test_predict, labels=["pos", "neg"])

# %%
labels=["pos", "neg"]

sns.heatmap(cm, linewidth = 0.5, annot = True, cmap = 'Reds', fmt = 'g', 
            xticklabels=labels, yticklabels=labels)

plt.ylabel('Valores predecidos')
plt.xlabel('Valores reales')
plt.title('Comparación con valores de entrenamiento')
plt.show()

# %%
print(classification_report(y_test, y_test_predict))
# Out:
#               precision    recall  f1-score   support
#
#          neg       0.78      0.86      0.82        93
#          pos       0.87      0.79      0.82       107
#
#     accuracy                           0.82       200
#    macro avg       0.82      0.82      0.82       200
# weighted avg       0.82      0.82      0.82       200
